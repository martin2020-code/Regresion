# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y = np.loadtxt('data/scattered.dat',delimiter=' ',unpack=True)

# %%
plt.scatter(x,y)

# %%
x,y = np.loadtxt('pyreg/scattered.dat').T
plt.scatter(x,y)

# %%
A,B,err = np.loadtxt('data/minima.dat',delimiter=' ', unpack=True)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter3D(A,B,err)
